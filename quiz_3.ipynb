# %%
import pandas as pd
belize_listings_path = "belize_airbnb_listings.csv"
belize_df = pd.read_csv(belize_listings_path)
belize_df.tail()
# Out:
#             id                                               name    host_id  \
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
#           host_name neighbourhood_group   neighbourhood   latitude  longitude  \
# 2791         Ronald              Belize  Belize Islands  17.945690 -87.944620
# 2792        Michael             Corozal         Corozal  18.374630 -88.400190
# 2793  Vacasa Belize              Belize  Belize Islands  17.934580 -87.955220
# 2794      Alexandra              Belize  Belize Islands  17.930010 -87.957120
# 2795    San Ignacio                Cayo            Cayo  17.154127 -89.069689
#
# ...

# %%
belize_df.sort_values(by= ['neighbourhood'])
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1057  22957664  Beach side cottage with kitchenette, "delrio",...   12050173
# 1056  22957076   Private beach, Beach cottage + AC "del rio"- RCG   87759528
# 1055  22956555              Ocean Front 3 Bedroom Penthouse (24B)   54276523
# 1053  22954440   STUNNING VIEW!! The White House-Oceanfront 3B4Ba     722631
# ...        ...                                                ...        ...
# 1790  34418855                                  Big Falls Retreat  259822217
# 2460  43187209               Luxury Canopy Suite Above the Jungle    4724014
# 505   15852773                       900 sq ft Cassita with pool!  102641960
# 501   15845226                       600 sq ft Cassita with pool!  102641960
# 651   17663193              The Jungle meets the Caribbean Beach.   65825079
#
# ...

# %%
belize_df[["price"]].mean()
# Out:
# price    357.102289
# dtype: float64

# %%
belize_df[["number_of_reviews"]].sum()
# Out:
# number_of_reviews    40412
# dtype: int64

# %%
belize_df[["availability_365"]].max()
